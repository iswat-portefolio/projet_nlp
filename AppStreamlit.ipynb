# %% [markdown]
# <a href="https://colab.research.google.com/github/iswat-portefolio/projet_nlp/blob/main/AppStreamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Étape 1 : Installation des dépendances

# %%
# Installation de Streamlit
# !pip install -q streamlit

# Installation de localtunnel
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦
# changed 22 packages in 796ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦

# %%
#Étape 2 : Créer ton application Streamlit
# %%writefile app.py
import streamlit as st
import pandas as pd

st.set_page_config(page_title="Assistant NLP BBC", layout="wide")

st.title("🤖 Assistant Intelligent de Résumé et d'Extraction")
st.markdown("---")

# Zone de téléchargement
uploaded_file = st.file_uploader("Charger un document (TXT)", type="txt")

if uploaded_file:
    text = uploaded_file.read().decode("utf-8")

    col1, col2 = st.columns(2)

    with col1:
        st.subheader("Options d'analyse")
        model_type = st.selectbox("Modèle de classification", ["LSTM", "BERT", "DistilBERT"])
        if st.button("Lancer la classification"):
            st.info(f"Résultat : Thématique prédite via {model_type}")

    with col2:
        st.subheader("Visualisation")
        st.text_area("Aperçu du texte", text[:1000], height=200)
# Out:
# Overwriting app.py

# %% [markdown]
# Étape 3 : Lancer l'application et obtenir l'URL

# %%
import urllib
print("Ton mot de passe (IP) pour le tunnel est :", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
# Out:
# Ton mot de passe (IP) pour le tunnel est : 34.86.74.103

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹⠸
# ...
#
# ⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹your url is: https://hip-yaks-melt.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.86.74.103:8501
